# %% [markdown]
# <a href="https://colab.research.google.com/github/dakshini01/ProdFusion/blob/main/codes/Data_Identification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv("garments_worker_productivity.csv")
#print(df.head())
# Out:
#      <input type="file" id="files-7fb561d6-d433-4f93-a8ca-f47223d62387" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fb561d6-d433-4f93-a8ca-f47223d62387">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.shape
# Out:
# (1197, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %%
df.head()
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# ...

# %%
df.describe(include='all')
# Out:
#              date   quarter department        day         team  \
# count        1197      1197       1197       1197  1197.000000
# unique         59         5          3          6          NaN
# top     1/31/2015  Quarter1     sweing  Wednesday          NaN
# freq           24       360        691        208          NaN
# mean          NaN       NaN        NaN        NaN     6.426901
# std           NaN       NaN        NaN        NaN     3.463963
# min           NaN       NaN        NaN        NaN     1.000000
# 25%           NaN       NaN        NaN        NaN     3.000000
# 50%           NaN       NaN        NaN        NaN     6.000000
# 75%           NaN       NaN        NaN        NaN     9.000000
# max           NaN       NaN        NaN        NaN    12.000000
#
#         targeted_productivity          smv           wip     over_time  \
# count             1197.000000  1197.000000    691.000000   1197.000000
# ...

# %%
#compute correlation
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include=[np.number])

plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
df.isnull().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
df.groupby('department')['wip'].apply(lambda x: x.isnull().sum())
# Out:
# department
# finishing     249
# finishing     257
# sweing          0
# Name: wip, dtype: int64

# %%
#productivity over teams
sns.boxplot(x="team", y="actual_productivity", data=df)
plt.xticks(rotation=90)
plt.title("Productivity Variation Across Teams")
plt.show()

# %%
#incentive
sns.scatterplot(x="incentive", y="actual_productivity", data=df)
plt.title("Incentive vs Productivity")
plt.show()

# %%
#WIP
sns.scatterplot(x="wip", y="actual_productivity", data=df)
plt.title("WIP vs Productivity")
plt.show()

# %%
#no.of workers
sns.scatterplot(x="no_of_workers", y="actual_productivity", data=df)
plt.title("Workers vs Productivity")
plt.show()

# %%
#department
sns.boxplot(x="department", y="actual_productivity", data=df)
plt.title("Productivity by Department")
plt.show()

# %%
#weekday
sns.boxplot(x="day", y="actual_productivity", data=df)
plt.title("Productivity by Day of Week")
plt.show()
